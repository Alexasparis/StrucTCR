# %%
import os
os.chdir('/Users/alexascunceparis/Desktop/BSC/immuno_project/TCRranker')
from extract_contacts import extract_contacts

# %%
pdb_dir = './pdb_files/'  
pdb_files = [os.path.join(pdb_dir, f) for f in os.listdir(pdb_dir) if f.endswith('.pdb')]

chain_dict = {}
general_df = pd.read_csv('./structures_annotation/general.txt', sep='\t')

for pdb_id, group in general_df.groupby('pdb.id'):
    chains = {
        'tcra_chain': None,
        'tcrb_chain': None,
        'peptide_chain': None,
        'mhc_chain': None
    }
    
    for _, row in group.iterrows():
        if row['chain.component'] == 'TCR' and row['chain.type'] == 'TRA':
            chains['tcra_chain'] = row['chain.id']
        elif row['chain.component'] == 'TCR' and row['chain.type'] == 'TRB':
            chains['tcrb_chain'] = row['chain.id']
        elif row['chain.component'] == 'PEPTIDE':
            chains['peptide_chain'] = row['chain.id']
        elif row['chain.component'] == 'MHC' and row['chain.supertype'] == 'MHCI' and row['chain.type'] == 'MHCa':
            chains['mhc_chain'] = row['chain.id']
        
    chain_dict[pdb_id] = chains

# %%
for pdb_file in pdb_files:
    pdb_id = os.path.basename(pdb_file).split('.')[0]
    output_file = f'./contact_maps/{pdb_id}_contacts.csv'
    if os.path.exists(output_file):
        print(f"File {output_file} exists, omiting...")
        continue
    else:
        contacts_df = extract_contacts([pdb_file], chain_dict)
    contacts_df.to_csv(output_file, index=False)
    print(f"Saved contacts in {output_file}.")

# %% [markdown]
# #### SEE IF ALL CONTACT MAPS CAN BE USED

# %%
import os
import pandas as pd

def validate_chain_columns(csv_file):
    """
    Verifies that the 'chain_from' and 'chain_to' columns in the CSV file contain exactly 2 unique strings each.

    Args:
    - csv_file (str): Path to the CSV file.

    Returns:
    - bool: True if the condition is met, False otherwise.
    - dict: Dictionary containing the found strings in 'chain_from' and 'chain_to'.
    """
    # Load the CSV file
    df = pd.read_csv(csv_file)

    # Check if the 'chain_from' and 'chain_to' columns exist
    if 'chain_from' not in df.columns or 'chain_to' not in df.columns:
        raise ValueError(f"The file {csv_file} does not contain 'chain_from' or 'chain_to' columns.")

    # Get unique values in the 'chain_from' and 'chain_to' columns
    unique_chain_from = df['chain_from'].unique()
    unique_chain_to = df['chain_to'].unique()

    # Validate that both columns have exactly 2 unique strings
    is_valid = len(unique_chain_from) == 2 and len(unique_chain_to) == 2

    # Return the result and the found chains
    return is_valid, {'chain_from': unique_chain_from, 'chain_to': unique_chain_to}

def check_contact_maps(directory):
    """
    Iterates through the contact_maps folder and checks each CSV file to ensure that 'chain_from' and 'chain_to' have 2 unique strings each.

    Args:
    - directory (str): Directory containing the CSV files.
    """
    # Verify that the directory exists
    if not os.path.isdir(directory):
        raise ValueError(f"The directory {directory} does not exist.")

    # List all files in the directory
    for file_name in os.listdir(directory):
        if file_name.endswith('_contacts.csv'):
            file_path = os.path.join(directory, file_name)
            try:
                is_valid, chains = validate_chain_columns(file_path)
                if is_valid:
                    print(f"File {file_name} is valid.")
                else:
                    print(f"File {file_name} is not valid. Chains found: {chains}")
            except Exception as e:
                print(f"Error processing {file_name}: {e}")

check_contact_maps('./contact_maps/')
# Out:
# Archivo 7n2p_contacts.csv es válido.
# Archivo 4jfd_contacts.csv es válido.
# Archivo 7l1d_contacts.csv es válido.
# Archivo 2gj6_contacts.csv es válido.
# Archivo 4jry_contacts.csv es válido.
# Archivo 5wkf_contacts.csv es válido.
# Archivo 2ckb_contacts.csv es válido.
# Archivo 7jwj_contacts.csv es válido.
# Archivo 8gvb_contacts.csv es válido.
# Archivo 5ivx_contacts.csv es válido.
# Archivo 2ypl_contacts.csv es válido.
# Archivo 5isz_contacts.csv es válido.
# Archivo 7n4k_contacts.csv es válido.
# Archivo 6bj3_contacts.csv es válido.
# Archivo 1mwa_contacts.csv es válido.
# Archivo 5c0b_contacts.csv es válido.
# Archivo 5c08_contacts.csv es válido.
# Archivo 3e3q_contacts.csv es válido.
# Archivo 5wlg_contacts.csv es válido.
# Archivo 7n2o_contacts.csv es válido.
# Archivo 5jhd_contacts.csv es válido.
# Archivo 6vm7_contacts.csv es válido.
# Archivo 6zkz_contacts.csv es válido.
# Archivo 4ftv_contacts.csv es válido.
# Archivo 3rgv_contacts.csv es válido.
# Archivo 8gom_contacts.csv es válido.
# Archivo 7pb2_contacts.csv es válido.
# Archivo 4ms8_contacts.csv es válido.
# Archivo 2ak4_contacts.csv es válido.
# Archivo 8wul_contacts.csv es válido.
# Archivo 3uts_contacts.csv es válido.
# Archivo 1nam_contacts.csv es válido.
# Archivo 3utt_contacts.csv es válido.
# Archivo 8en8_contacts.csv es válido.
# Archivo 8shi_contacts.csv es válido.
# Archivo 4jfe_contacts.csv es válido.
# Archivo 1mi5_contacts.csv es válido.
# Archivo 5eu6_contacts.csv es válido.
# Archivo 3tfk_contacts.csv es válido.
# Archivo 2p5e_contacts.csv es válido.
# Archivo 1qse_contacts.csv es válido.
# Archivo 7n2q_contacts.csv es válido.
# Archivo 3d3v_contacts.csv es válido.
# Archivo 4jrx_contacts.csv es válido.
# Archivo 1kj2_contacts.csv es válido.
# Archivo 5hho_contacts.csv es válido.
# Archivo 2esv_contacts.csv es válido.
# Archivo 4n0c_contacts.csv es válido.
# Archivo 3gsn_contacts.csv es válido.
# Archivo 7rrg_contacts.csv es válido.
# Archivo 2j8u_contacts.csv es válido.
# Archivo 7n5p_contacts.csv es válido.
# Archivo 4qok_contacts.csv es válido.
# Archivo 6eqb_contacts.csv es válido.
# Archivo 3hg1_contacts.csv es válido.
# Archivo 6bj2_contacts.csv es válido.
# Archivo 5c09_contacts.csv es válido.
# Archivo 5c0c_contacts.csv es válido.
# Archivo 5men_contacts.csv es válido.
# Archivo 7n2n_contacts.csv es válido.
# Archivo 3tpu_contacts.csv es válido.
# Archivo 2ol3_contacts.csv es válido.
# Archivo 6r2l_contacts.csv es válido.
# Archivo 6bj8_contacts.csv es válido.
# Archivo 3d39_contacts.csv es válido.
# Archivo 7ndq_contacts.csv es válido.
# Archivo 2vlk_contacts.csv es válido.
# Archivo 6rp9_contacts.csv es válido.
# Archivo 6vma_contacts.csv es válido.
# Archivo 7ow6_contacts.csv es válido.
# Archivo 2p5w_contacts.csv es válido.
# Archivo 7q9b_contacts.csv es válido.
# Archivo 1ao7_contacts.csv es válido.
# Archivo 5w1v_contacts.csv es válido.
# Archivo 6uon_contacts.csv es válido.
# Archivo 3tjh_contacts.csv es válido.
# Archivo 5nmf_contacts.csv es válido.
# Archivo 5m02_contacts.csv es válido.
# Archivo 6am5_contacts.csv es válido.
# Archivo 5jzi_contacts.csv es válido.
# Archivo 6mtm_contacts.csv es válido.
# Archivo 7nme_contacts.csv es válido.
# Archivo 2bnr_contacts.csv es válido.
# Archivo 7pbe_contacts.csv es válido.
# Archivo 4l3e_contacts.csv es válido.
# Archivo 5e9d_contacts.csv es válido.
# Archivo 1fo0_contacts.csv es válido.
# Archivo 8gvi_contacts.csv es válido.
# Archivo 4pri_contacts.csv es válido.
# Archivo 6l9l_contacts.csv es válido.
# Archivo 8enh_contacts.csv es válido.
# Archivo 4qrp_contacts.csv es válido.
# Archivo 7n1e_contacts.csv es válido.
# Archivo 5nmg_contacts.csv es válido.
# Archivo 6zkw_contacts.csv es válido.
# Archivo 5w1w_contacts.csv es válido.
# Archivo 5nqk_contacts.csv es válido.
# Archivo 7q99_contacts.csv es válido.
# Archivo 5sws_contacts.csv es válido.
# Archivo 3sjv_contacts.csv es válido.
# Archivo 3mv7_contacts.csv es válido.
# Archivo 4prp_contacts.csv es válido.
# Archivo 3qfj_contacts.csv es válido.
# Archivo 7n6e_contacts.csv es válido.
# Archivo 4g8g_contacts.csv es válido.
# Archivo 2vlj_contacts.csv es válido.
# Archivo 6rpb_contacts.csv es válido.
# Archivo 5tje_contacts.csv es válido.
# Archivo 5d2l_contacts.csv es válido.
# Archivo 3kxf_contacts.csv es válido.
# Archivo 7dzm_contacts.csv es válido.
# Archivo 3ffc_contacts.csv es válido.
# Archivo 7pbc_contacts.csv es válido.
# Archivo 8d5q_contacts.csv es válido.
# Archivo 4prh_contacts.csv es válido.
# Archivo 5yxn_contacts.csv es válido.
# Archivo 3dxa_contacts.csv es válido.
# Archivo 8i5c_contacts.csv es válido.
# Archivo 1bd2_contacts.csv es válido.
# Archivo 6vrm_contacts.csv es válido.
# Archivo 8i5d_contacts.csv es válido.
# Archivo 7r80_contacts.csv es válido.
# Archivo 8cx4_contacts.csv es válido.
# Archivo 6uln_contacts.csv es válido.
# Archivo 6vmx_contacts.csv es válido.
# Archivo 8wte_contacts.csv es válido.
# Archivo 7n5c_contacts.csv es válido.
# Archivo 2vlr_contacts.csv es válido.
# Archivo 5xot_contacts.csv es válido.
# Archivo 5m01_contacts.csv es válido.
# Archivo 7nmf_contacts.csv es válido.
# Archivo 6rsy_contacts.csv es válido.
# Archivo 1g6r_contacts.csv es válido.
# Archivo 7q9a_contacts.csv es válido.
# Archivo 5nme_contacts.csv es válido.
# Archivo 6tmo_contacts.csv es válido.
# Archivo 7ow5_contacts.csv es válido.
# Archivo 6vm8_contacts.csv es válido.
# Archivo 2e7l_contacts.csv es válido.
# Archivo 5d2n_contacts.csv es válido.
# Archivo 3kpr_contacts.csv es válido.
# Archivo 5c07_contacts.csv es válido.
# Archivo 7ndu_contacts.csv es válido.
# Archivo 3qeq_contacts.csv es válido.
# Archivo 7rtr_contacts.csv es válido.
# Archivo 8f5a_contacts.csv es válido.
# Archivo 7n1f_contacts.csv es válido.
# Archivo 6avf_contacts.csv es válido.
# Archivo 1qrn_contacts.csv es válido.
# Archivo 6d78_contacts.csv es válido.
# Archivo 4eup_contacts.csv es válido.
# Archivo 7na5_contacts.csv es válido.
# Archivo 5xov_contacts.csv es válido.
# Archivo 1oga_contacts.csv es válido.
# Archivo 2bnq_contacts.csv es válido.
# Archivo 2oi9_contacts.csv es válido.
# Archivo 6vqo_contacts.csv es válido.
# Archivo 6vmc_contacts.csv es válido.
# Archivo 6vm9_contacts.csv es válido.
# Archivo 7dzn_contacts.csv es válido.
# Archivo 6ulr_contacts.csv es válido.
# Archivo 5brz_contacts.csv es válido.
# Archivo 3o4l_contacts.csv es válido.
# Archivo 6rpa_contacts.csv es válido.
# Archivo 7ndt_contacts.csv es válido.
# Archivo 3kps_contacts.csv es válido.
# Archivo 7phr_contacts.csv es válido.
# Archivo 8qfy_contacts.csv es válido.
# Archivo 7nmg_contacts.csv es válido.
# Archivo 5yxu_contacts.csv es válido.
# Archivo 5m00_contacts.csv es válido.
# Archivo 4g9f_contacts.csv es válido.
# Archivo 5wkh_contacts.csv es válido.
# Archivo 6avg_contacts.csv es válido.
# Archivo 3qdj_contacts.csv es válido.
# Archivo 4qrr_contacts.csv es válido.
# Archivo 6vrn_contacts.csv es válido.
# Archivo 3qdm_contacts.csv es válido.
# Archivo 8dnt_contacts.csv es válido.
# Archivo 6amu_contacts.csv es válido.
# Archivo 2jcc_contacts.csv es válido.
# Archivo 5e6i_contacts.csv es válido.
# Archivo 3pwp_contacts.csv es válido.
# Archivo 3qdg_contacts.csv es válido.
# Archivo 5nht_contacts.csv es válido.
# Archivo 7byd_contacts.csv es válido.
# Archivo 4mvb_contacts.csv es válido.
# Archivo 7jwi_contacts.csv es válido.
# Archivo 3e2h_contacts.csv es válido.
# Archivo 4mji_contacts.csv es válido.
# Archivo 5bs0_contacts.csv es válido.
# Archivo 3vxs_contacts.csv es válido.
# Archivo 5hyj_contacts.csv es válido.
# Archivo 2pye_contacts.csv es válido.
# Archivo 8eo8_contacts.csv es válido.
# Archivo 7n2s_contacts.csv es válido.
# Archivo 3mv9_contacts.csv es válido.
# Archivo 2uwe_contacts.csv es válido.
# Archivo 5swz_contacts.csv es válido.
# Archivo 5hhm_contacts.csv es válido.
# Archivo 3w0w_contacts.csv es válido.
# Archivo 6zky_contacts.csv es válido.
# Archivo 4mnq_contacts.csv es válido.
# Archivo 2nx5_contacts.csv es válido.
# Archivo 6p64_contacts.csv es válido.
# Archivo 5c0a_contacts.csv es válido.
# Archivo 7qpj_contacts.csv es válido.
# Archivo 3pqy_contacts.csv es válido.
# Archivo 7rm4_contacts.csv es válido.
# Archivo 7pdw_contacts.csv es válido.
# Archivo 5tez_contacts.csv es válido.
# Archivo 3h9s_contacts.csv es válido.
# Archivo 4jff_contacts.csv es válido.
# Archivo 6tro_contacts.csv es válido.
# Archivo 5euo_contacts.csv es válido.
# Archivo 1qsf_contacts.csv es válido.
# Archivo 7n2r_contacts.csv es válido.
# Archivo 6dkp_contacts.csv es válido.
# Archivo 8gon_contacts.csv es válido.
# Archivo 3vxu_contacts.csv es válido.
# Archivo 5til_contacts.csv es válido.
# Archivo 6g9q_contacts.csv es válido.
# Archivo 3vxr_contacts.csv es válido.
# Archivo 8gvg_contacts.csv es válido.
# Archivo 4mxq_contacts.csv es válido.
# Archivo 1lp9_contacts.csv es válido.
# Archivo 6q3s_contacts.csv es válido.
# Archivo 6eqa_contacts.csv es válido.
# Archivo 4n5e_contacts.csv es válido.
# Archivo 3vxm_contacts.csv es válido.
# Archivo 7rk7_contacts.csv es válido.
# Archivo 3mv8_contacts.csv es válido.
# Archivo 2f54_contacts.csv es válido.
# Archivo 6zkx_contacts.csv es válido.
# Archivo 2f53_contacts.csv es válido.
