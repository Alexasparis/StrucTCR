# %% [markdown]
# # IMPORT LIBRARIES

# %%
import os
import pandas as pd
os.chdir('/Users/alexascunceparis/Desktop/BSC/TCRranker_v3')
from extract_contacts import extract_contacts
from utils import parse_general_file

# %%
# Chain info dict:{'1ao7': {'tcra_chain': 'D',
#  'tcrb_chain': 'E',
#  'peptide_chain': 'C',
#  'mhc_chain': 'A'},
# '1bd2': {'tcra_chain': 'D',
#  'tcrb_chain': 'E'...}

chain_dict=parse_general_file('./structures_annotation/general.txt')

# %% [markdown]
# # EXTRACT CONTACTS

# %%
import os

# Loop through all files in the pdb_files directory
for pdb_file in os.listdir('./pdb_files/'):
    # Check if the file is a CSV file
    if pdb_file.endswith('.pdb'):
        pdb_id = os.path.basename(pdb_file).split('.')[0]  # Extract PDB ID from the file name
        pdb_path = f'./pdb_files/{pdb_file}'  # Path to the current PDB file
        
        # Create the output directory if it doesn't exist
        if not os.path.exists('./contact_maps'):
            os.makedirs('./contact_maps')
        
        # Define the output file path for the contact map
        output_file = f'./contact_maps/{pdb_id}_contacts.csv'
        
        # Check if the contact map already exists
        if os.path.exists(output_file):
            # If it exists, print a message and skip processing this file
            print(f"File {output_file} exists, omitting...")
            continue
        else:
            if pdb_id in chain_dict:
                contacts_df = extract_contacts([pdb_path], chain_dict)
                contacts_df.to_csv(output_file, index=False)  # Save the contact map to the output file
                print(f"Saved contacts in {output_file}.")
            else:
                print(f"Chain info not found for {pdb_id}. Using default chains...")
                chain_dict = {f'{pdb_id}': {'tcra_chain': 'D',
                                            'tcrb_chain': 'E',
                                            'peptide_chain': 'C',
                                            'b2m_chain': 'B',
                                            'mhc_chain': 'A'}}

                contacts_df = extract_contacts([pdb_path], chain_dict)
                contacts_df.to_csv(output_file, index=False)  # Save the contact map to the output file
                print(f"Saved contacts in {output_file}.")
# Out:
# File ./contact_maps/2ckb_contacts.csv exists, omitting...
# File ./contact_maps/5m02_contacts.csv exists, omitting...
# File ./contact_maps/8cx4_contacts.csv exists, omitting...
# File ./contact_maps/5tez_contacts.csv exists, omitting...
# File ./contact_maps/7n4k_contacts.csv exists, omitting...
# File ./contact_maps/7rrg_contacts.csv exists, omitting...
# File ./contact_maps/3vxs_contacts.csv exists, omitting...
# File ./contact_maps/5nmf_contacts.csv exists, omitting...
# File ./contact_maps/7jwi_contacts.csv exists, omitting...
# File ./contact_maps/8i5d_contacts.csv exists, omitting...
# File ./contact_maps/3mv9_contacts.csv exists, omitting...
# File ./contact_maps/8rym_contacts.csv exists, omitting...
# File ./contact_maps/3qdm_contacts.csv exists, omitting...
# File ./contact_maps/3mv8_contacts.csv exists, omitting...
# File ./contact_maps/8gon_contacts.csv exists, omitting...
# File ./contact_maps/3d3v_contacts.csv exists, omitting...
# File ./contact_maps/5nmg_contacts.csv exists, omitting...
# File ./contact_maps/3vxr_contacts.csv exists, omitting...
# File ./contact_maps/8enh_contacts.csv exists, omitting...
# File ./contact_maps/5men_contacts.csv exists, omitting...
# File ./contact_maps/5m01_contacts.csv exists, omitting...
# File ./contact_maps/2jcc_contacts.csv exists, omitting...
# File ./contact_maps/8qfy_contacts.csv exists, omitting...
# File ./contact_maps/7na5_contacts.csv exists, omitting...
# File ./contact_maps/5swz_contacts.csv exists, omitting...
# File ./contact_maps/2esv_contacts.csv exists, omitting...
# File ./contact_maps/8eo8_contacts.csv exists, omitting...
# File ./contact_maps/5nme_contacts.csv exists, omitting...
# File ./contact_maps/7jwj_contacts.csv exists, omitting...
# File ./contact_maps/3o4l_contacts.csv exists, omitting...
# File ./contact_maps/8ryn_contacts.csv exists, omitting...
# Extracting contacts from 8yj2
# Saved contacts in ./contact_maps/8yj2_contacts.csv.
# File ./contact_maps/8ryo_contacts.csv exists, omitting...
# File ./contact_maps/8gom_contacts.csv exists, omitting...
# File ./contact_maps/2gj6_contacts.csv exists, omitting...
# File ./contact_maps/5jzi_contacts.csv exists, omitting...
# File ./contact_maps/2ak4_contacts.csv exists, omitting...
# File ./contact_maps/2j8u_contacts.csv exists, omitting...
# File ./contact_maps/5til_contacts.csv exists, omitting...
# File ./contact_maps/5m00_contacts.csv exists, omitting...
# File ./contact_maps/6amu_contacts.csv exists, omitting...
# File ./contact_maps/6vmx_contacts.csv exists, omitting...
# File ./contact_maps/6vm9_contacts.csv exists, omitting...
# Extracting contacts from 8v50
# Saved contacts in ./contact_maps/8v50_contacts.csv.
# File ./contact_maps/6mtm_contacts.csv exists, omitting...
# File ./contact_maps/1qsf_contacts.csv exists, omitting...
# File ./contact_maps/7n6e_contacts.csv exists, omitting...
# File ./contact_maps/7nme_contacts.csv exists, omitting...
# File ./contact_maps/6bj2_contacts.csv exists, omitting...
# File ./contact_maps/4mnq_contacts.csv exists, omitting...
# File ./contact_maps/3vxu_contacts.csv exists, omitting...
# File ./contact_maps/4jry_contacts.csv exists, omitting...
# File ./contact_maps/3qdj_contacts.csv exists, omitting...
# File ./contact_maps/4jrx_contacts.csv exists, omitting...
# File ./contact_maps/8i5c_contacts.csv exists, omitting...
# File ./contact_maps/7q99_contacts.csv exists, omitting...
# File ./contact_maps/6bj3_contacts.csv exists, omitting...
# File ./contact_maps/5wlg_contacts.csv exists, omitting...
# File ./contact_maps/8en8_contacts.csv exists, omitting...
# File ./contact_maps/6dkp_contacts.csv exists, omitting...
# File ./contact_maps/6q3s_contacts.csv exists, omitting...
# Extracting contacts from 8v51
# Saved contacts in ./contact_maps/8v51_contacts.csv.
# File ./contact_maps/6vm8_contacts.csv exists, omitting...
# File ./contact_maps/5tje_contacts.csv exists, omitting...
# File ./contact_maps/6am5_contacts.csv exists, omitting...
# File ./contact_maps/3w0w_contacts.csv exists, omitting...
# File ./contact_maps/5c08_contacts.csv exists, omitting...
# File ./contact_maps/1qse_contacts.csv exists, omitting...
# File ./contact_maps/4l3e_contacts.csv exists, omitting...
# File ./contact_maps/7nmf_contacts.csv exists, omitting...
# File ./contact_maps/3hg1_contacts.csv exists, omitting...
# File ./contact_maps/1lp9_contacts.csv exists, omitting...
# File ./contact_maps/4mvb_contacts.csv exists, omitting...
# File ./contact_maps/5yxn_contacts.csv exists, omitting...
# File ./contact_maps/1bd2_contacts.csv exists, omitting...
# File ./contact_maps/8gvi_contacts.csv exists, omitting...
# File ./contact_maps/2uwe_contacts.csv exists, omitting...
# File ./contact_maps/3sjv_contacts.csv exists, omitting...
# File ./contact_maps/7nmg_contacts.csv exists, omitting...
# File ./contact_maps/6tmo_contacts.csv exists, omitting...
# File ./contact_maps/5c09_contacts.csv exists, omitting...
# File ./contact_maps/1ao7_contacts.csv exists, omitting...
# File ./contact_maps/7rk7_contacts.csv exists, omitting...
# File ./contact_maps/3kxf_contacts.csv exists, omitting...
# File ./contact_maps/4eup_contacts.csv exists, omitting...
# File ./contact_maps/2vlj_contacts.csv exists, omitting...
# File ./contact_maps/3pqy_contacts.csv exists, omitting...
# File ./contact_maps/3rgv_contacts.csv exists, omitting...
# File ./contact_maps/5hho_contacts.csv exists, omitting...
# File ./contact_maps/5nqk_contacts.csv exists, omitting...
# File ./contact_maps/2p5e_contacts.csv exists, omitting...
# File ./contact_maps/5wkf_contacts.csv exists, omitting...
# File ./contact_maps/5xov_contacts.csv exists, omitting...
# File ./contact_maps/7n1e_contacts.csv exists, omitting...
# File ./contact_maps/2vlk_contacts.csv exists, omitting...
# File ./contact_maps/7rtr_contacts.csv exists, omitting...
# File ./contact_maps/1oga_contacts.csv exists, omitting...
# File ./contact_maps/4prh_contacts.csv exists, omitting...
# File ./contact_maps/5xot_contacts.csv exists, omitting...
# File ./contact_maps/5w1w_contacts.csv exists, omitting...
# File ./contact_maps/5w1v_contacts.csv exists, omitting...
# File ./contact_maps/4mji_contacts.csv exists, omitting...
# File ./contact_maps/6uln_contacts.csv exists, omitting...
# File ./contact_maps/5hhm_contacts.csv exists, omitting...
# File ./contact_maps/4pri_contacts.csv exists, omitting...
# File ./contact_maps/7n1f_contacts.csv exists, omitting...
# File ./contact_maps/7l1d_contacts.csv exists, omitting...
# File ./contact_maps/3uts_contacts.csv exists, omitting...
# File ./contact_maps/1fo0_contacts.csv exists, omitting...
# File ./contact_maps/6vrn_contacts.csv exists, omitting...
# File ./contact_maps/7n2n_contacts.csv exists, omitting...
# File ./contact_maps/6rpb_contacts.csv exists, omitting...
# File ./contact_maps/6rsy_contacts.csv exists, omitting...
# File ./contact_maps/8rro_contacts.csv exists, omitting...
# File ./contact_maps/5ivx_contacts.csv exists, omitting...
# File ./contact_maps/2ypl_contacts.csv exists, omitting...
# File ./contact_maps/4ms8_contacts.csv exists, omitting...
# File ./contact_maps/5e6i_contacts.csv exists, omitting...
# File ./contact_maps/5euo_contacts.csv exists, omitting...
# File ./contact_maps/4ftv_contacts.csv exists, omitting...
# File ./contact_maps/5brz_contacts.csv exists, omitting...
# File ./contact_maps/6zkw_contacts.csv exists, omitting...
# File ./contact_maps/7n2o_contacts.csv exists, omitting...
# File ./contact_maps/6tro_contacts.csv exists, omitting...
# File ./contact_maps/3utt_contacts.csv exists, omitting...
# File ./contact_maps/6vrm_contacts.csv exists, omitting...
# File ./contact_maps/3gsn_contacts.csv exists, omitting...
# File ./contact_maps/3e3q_contacts.csv exists, omitting...
# File ./contact_maps/8wul_contacts.csv exists, omitting...
# File ./contact_maps/1kj2_contacts.csv exists, omitting...
# File ./contact_maps/6rpa_contacts.csv exists, omitting...
# File ./contact_maps/5e9d_contacts.csv exists, omitting...
# File ./contact_maps/7qpj_contacts.csv exists, omitting...
# File ./contact_maps/2p5w_contacts.csv exists, omitting...
# File ./contact_maps/4n5e_contacts.csv exists, omitting...
# File ./contact_maps/7rm4_contacts.csv exists, omitting...
# File ./contact_maps/8f5a_contacts.csv exists, omitting...
# File ./contact_maps/5jhd_contacts.csv exists, omitting...
# File ./contact_maps/8dnt_contacts.csv exists, omitting...
# File ./contact_maps/7ndq_contacts.csv exists, omitting...
# File ./contact_maps/6d78_contacts.csv exists, omitting...
# File ./contact_maps/6zky_contacts.csv exists, omitting...
# File ./contact_maps/6ulr_contacts.csv exists, omitting...
# File ./contact_maps/6l9l_contacts.csv exists, omitting...
# File ./contact_maps/3h9s_contacts.csv exists, omitting...
# File ./contact_maps/2pye_contacts.csv exists, omitting...
# File ./contact_maps/3tfk_contacts.csv exists, omitting...
# File ./contact_maps/8wte_contacts.csv exists, omitting...
# File ./contact_maps/5bs0_contacts.csv exists, omitting...
# File ./contact_maps/5eu6_contacts.csv exists, omitting...
# File ./contact_maps/3tjh_contacts.csv exists, omitting...
# File ./contact_maps/7pbc_contacts.csv exists, omitting...
# Extracting contacts from 6zkx
# Saved contacts in ./contact_maps/6zkx_contacts.csv.
# File ./contact_maps/1mi5_contacts.csv exists, omitting...
# File ./contact_maps/5d2n_contacts.csv exists, omitting...
# File ./contact_maps/5d2l_contacts.csv exists, omitting...
# File ./contact_maps/6zkz_contacts.csv exists, omitting...
# File ./contact_maps/6r2l_contacts.csv exists, omitting...
# File ./contact_maps/5nht_contacts.csv exists, omitting...
# File ./contact_maps/4qok_contacts.csv exists, omitting...
# File ./contact_maps/6rp9_contacts.csv exists, omitting...
# File ./contact_maps/6vqo_contacts.csv exists, omitting...
# File ./contact_maps/7r80_contacts.csv exists, omitting...
# File ./contact_maps/3kpr_contacts.csv exists, omitting...
# File ./contact_maps/2vlr_contacts.csv exists, omitting...
# File ./contact_maps/7n2p_contacts.csv exists, omitting...
# File ./contact_maps/3e2h_contacts.csv exists, omitting...
# File ./contact_maps/7pb2_contacts.csv exists, omitting...
# File ./contact_maps/5wkh_contacts.csv exists, omitting...
# File ./contact_maps/1nam_contacts.csv exists, omitting...
# Extracting contacts from 8es9
# Saved contacts in ./contact_maps/8es9_contacts.csv.
# File ./contact_maps/6eqb_contacts.csv exists, omitting...
# File ./contact_maps/3dxa_contacts.csv exists, omitting...
# File ./contact_maps/2e7l_contacts.csv exists, omitting...
# File ./contact_maps/7ow6_contacts.csv exists, omitting...
# Extracting contacts from 8es8
# Saved contacts in ./contact_maps/8es8_contacts.csv.
# File ./contact_maps/6uon_contacts.csv exists, omitting...
# File ./contact_maps/7pbe_contacts.csv exists, omitting...
# File ./contact_maps/7n2q_contacts.csv exists, omitting...
# File ./contact_maps/3kps_contacts.csv exists, omitting...
# File ./contact_maps/4prp_contacts.csv exists, omitting...
# File ./contact_maps/7ndt_contacts.csv exists, omitting...
# File ./contact_maps/7n2s_contacts.csv exists, omitting...
# File ./contact_maps/8d5q_contacts.csv exists, omitting...
# Extracting contacts from 8rj5
# Saved contacts in ./contact_maps/8rj5_contacts.csv.
# File ./contact_maps/3tpu_contacts.csv exists, omitting...
# File ./contact_maps/6eqa_contacts.csv exists, omitting...
# File ./contact_maps/7ow5_contacts.csv exists, omitting...
# File ./contact_maps/2ol3_contacts.csv exists, omitting...
# File ./contact_maps/7n2r_contacts.csv exists, omitting...
# File ./contact_maps/7ndu_contacts.csv exists, omitting...
# Extracting contacts from 8v4z
# Saved contacts in ./contact_maps/8v4z_contacts.csv.
# File ./contact_maps/5c0b_contacts.csv exists, omitting...
# File ./contact_maps/6avg_contacts.csv exists, omitting...
# File ./contact_maps/7q9a_contacts.csv exists, omitting...
# File ./contact_maps/4jfd_contacts.csv exists, omitting...
# File ./contact_maps/3vxm_contacts.csv exists, omitting...
# File ./contact_maps/5yxu_contacts.csv exists, omitting...
# File ./contact_maps/2bnq_contacts.csv exists, omitting...
# File ./contact_maps/4jfe_contacts.csv exists, omitting...
# File ./contact_maps/2oi9_contacts.csv exists, omitting...
# File ./contact_maps/2f54_contacts.csv exists, omitting...
# File ./contact_maps/7pdw_contacts.csv exists, omitting...
# File ./contact_maps/7n5p_contacts.csv exists, omitting...
# File ./contact_maps/6avf_contacts.csv exists, omitting...
# File ./contact_maps/5c0c_contacts.csv exists, omitting...
# File ./contact_maps/6vm7_contacts.csv exists, omitting...
# File ./contact_maps/6vma_contacts.csv exists, omitting...
# File ./contact_maps/6vmc_contacts.csv exists, omitting...
# File ./contact_maps/5c0a_contacts.csv exists, omitting...
# File ./contact_maps/5c07_contacts.csv exists, omitting...
# File ./contact_maps/1qrn_contacts.csv exists, omitting...
# File ./contact_maps/5sws_contacts.csv exists, omitting...
# File ./contact_maps/3pwp_contacts.csv exists, omitting...
# File ./contact_maps/7q9b_contacts.csv exists, omitting...
# File ./contact_maps/8gvg_contacts.csv exists, omitting...
# File ./contact_maps/8ye4_contacts.csv exists, omitting...
# File ./contact_maps/8ryp_contacts.csv exists, omitting...
# File ./contact_maps/3ffc_contacts.csv exists, omitting...
# Extracting contacts from 8yiv
# Saved contacts in ./contact_maps/8yiv_contacts.csv.
# File ./contact_maps/3qdg_contacts.csv exists, omitting...
# File ./contact_maps/8ryq_contacts.csv exists, omitting...
# File ./contact_maps/5isz_contacts.csv exists, omitting...
# File ./contact_maps/2bnr_contacts.csv exists, omitting...
# File ./contact_maps/4mxq_contacts.csv exists, omitting...
# File ./contact_maps/6g9q_contacts.csv exists, omitting...
# File ./contact_maps/4jff_contacts.csv exists, omitting...
# File ./contact_maps/4g8g_contacts.csv exists, omitting...
# File ./contact_maps/5hyj_contacts.csv exists, omitting...
# File ./contact_maps/1mwa_contacts.csv exists, omitting...
# File ./contact_maps/2f53_contacts.csv exists, omitting...
# File ./contact_maps/4qrp_contacts.csv exists, omitting...
# File ./contact_maps/8gvb_contacts.csv exists, omitting...
# File ./contact_maps/8rlt_contacts.csv exists, omitting...
# File ./contact_maps/3d39_contacts.csv exists, omitting...
# File ./contact_maps/7dzn_contacts.csv exists, omitting...
# File ./contact_maps/3qeq_contacts.csv exists, omitting...
# File ./contact_maps/3qfj_contacts.csv exists, omitting...
# File ./contact_maps/1g6r_contacts.csv exists, omitting...
# File ./contact_maps/3mv7_contacts.csv exists, omitting...
# File ./contact_maps/8rlu_contacts.csv exists, omitting...
# File ./contact_maps/7phr_contacts.csv exists, omitting...
# File ./contact_maps/4g9f_contacts.csv exists, omitting...
# File ./contact_maps/7n5c_contacts.csv exists, omitting...
# File ./contact_maps/6bj8_contacts.csv exists, omitting...
# File ./contact_maps/7dzm_contacts.csv exists, omitting...
# File ./contact_maps/6p64_contacts.csv exists, omitting...
# File ./contact_maps/2nx5_contacts.csv exists, omitting...
# File ./contact_maps/8rlv_contacts.csv exists, omitting...
# File ./contact_maps/4qrr_contacts.csv exists, omitting...
# File ./contact_maps/8shi_contacts.csv exists, omitting...
# File ./contact_maps/4n0c_contacts.csv exists, omitting...

# %% [markdown]
# #### SEE IF ALL CONTACT MAPS CAN BE USED
# Ensures each contact map has 2 chain_from (TCRa or TCRb) and 2 chain_to (MHC or Peptide)

# %%
def validate_chain_columns(csv_file, chain_dict):
    """
    Verifies that the 'chain_from' and 'chain_to' columns in the CSV file contain exactly 2 unique strings each,
    and that these chains match the expected types (TCRα, TCRβ, peptide, MHC).
    
    Args:
    - csv_file (str): Path to the CSV file.
    - chain_dict (dict): Dictionary containing expected chain types for each PDB file.
    
    Returns:
    - bool: True if the condition is met, False otherwise.
    - dict: Dictionary containing the found strings in 'chain_from' and 'chain_to'.
    """
    # Load the CSV file
    df = pd.read_csv(csv_file)

    # Check if the 'chain_from' and 'chain_to' columns exist
    if 'chain_from' not in df.columns or 'chain_to' not in df.columns:
        raise ValueError(f"The file {csv_file} does not contain 'chain_from' or 'chain_to' columns.")
    
    # Get the pdb_id from the file name (assuming the file name is structured as <pdb_id>_contacts.csv)
    pdb_id = os.path.basename(csv_file).split('_')[0]

    # Check if the pdb_id exists in chain_dict
    if pdb_id not in chain_dict:
        chain_dict = {f'{pdb_id}': {'tcra_chain': 'D',
                                    'tcrb_chain': 'E',
                                    'peptide_chain': 'C',
                                    'b2m_chain': 'B',
                                    'mhc_chain': 'A'}}
        print(f"Chain info not found for {pdb_id}. Using default chains...")
    
    # Retrieve the expected chains for this pdb_id
    expected_chains = chain_dict.get(pdb_id)
    expected_chain_from = [expected_chains['tcra_chain'], expected_chains['tcrb_chain']]  # TCR chains
    expected_chain_to = [expected_chains['peptide_chain'], expected_chains['mhc_chain']]  # Peptide and MHC chains

    # Get unique values in the 'chain_from' and 'chain_to' columns
    unique_chain_from = df['chain_from'].unique()
    unique_chain_to = df['chain_to'].unique()

    # Validate that both columns have exactly 2 unique strings and that the chains are expected
    is_valid = (len(unique_chain_from) == 2 and len(unique_chain_to) == 2 and
                all(chain in expected_chain_from for chain in unique_chain_from) and
                all(chain in expected_chain_to for chain in unique_chain_to))

    # Return the result and the found chains
    return is_valid, {'chain_from': unique_chain_from, 'chain_to': unique_chain_to}

def check_contact_maps(directory, chain_dict):
    """
    Iterates through the contact_maps folder and checks each CSV file to ensure that 'chain_from' and 'chain_to' 
    have 2 unique strings each, and that these chains match the expected TCR-peptide-MHC mapping.
    
    Args:
    - directory (str): Directory containing the CSV files.
    - chain_dict (dict): Dictionary containing expected chain types for each PDB file.
    """
    # Verify that the directory exists
    if not os.path.isdir(directory):
        raise ValueError(f"The directory {directory} does not exist.")

    # List all files in the directory
    for file_name in os.listdir(directory):
        if file_name.endswith('_contacts.csv'):
            file_path = os.path.join(directory, file_name)
            try:
                is_valid, chains = validate_chain_columns(file_path, chain_dict)
                if is_valid:
                    print(f"File {file_name} is valid.")
                else:
                    print(f"File {file_name} is not valid. Chains found: {chains}")
            
            except Exception as e:
                print(f"Error processing {file_name}: {e}")

# Check all CSV files in the 'contact_maps' folder
check_contact_maps('./contact_maps/', chain_dict)
# Out:
# File 7n2p_contacts.csv is valid.
# File 8rlv_contacts.csv is valid.
# File 4jfd_contacts.csv is valid.
# File 7l1d_contacts.csv is valid.
# File 2gj6_contacts.csv is valid.
# File 4jry_contacts.csv is valid.
# File 5wkf_contacts.csv is valid.
# File 2ckb_contacts.csv is valid.
# File 7jwj_contacts.csv is valid.
# File 8gvb_contacts.csv is valid.
# File 8ryn_contacts.csv is valid.
# File 5ivx_contacts.csv is valid.
# File 2ypl_contacts.csv is valid.
# File 5isz_contacts.csv is valid.
# File 7n4k_contacts.csv is valid.
# File 6bj3_contacts.csv is valid.
# File 1mwa_contacts.csv is valid.
# File 5c0b_contacts.csv is valid.
# File 5c08_contacts.csv is valid.
# File 3e3q_contacts.csv is valid.
# File 5wlg_contacts.csv is valid.
# File 7n2o_contacts.csv is valid.
# File 5jhd_contacts.csv is valid.
# File 6vm7_contacts.csv is valid.
# File 8v4z_contacts.csv is valid.
# File 8ryq_contacts.csv is valid.
# File 6zkz_contacts.csv is valid.
# File 4ftv_contacts.csv is valid.
# File 3rgv_contacts.csv is valid.
# File 8ye4_contacts.csv is valid.
# File 8gom_contacts.csv is valid.
# File 7pb2_contacts.csv is valid.
# File 4ms8_contacts.csv is valid.
# File 2ak4_contacts.csv is valid.
# File 8wul_contacts.csv is valid.
# File 3uts_contacts.csv is valid.
# File 1nam_contacts.csv is valid.
# File 3utt_contacts.csv is valid.
# File 8en8_contacts.csv is valid.
# File 8shi_contacts.csv is valid.
# File 8ryo_contacts.csv is valid.
# File 4jfe_contacts.csv is valid.
# File 1mi5_contacts.csv is valid.
# File 5eu6_contacts.csv is valid.
# File 3tfk_contacts.csv is valid.
# File 2p5e_contacts.csv is valid.
# File 1qse_contacts.csv is valid.
# File 7n2q_contacts.csv is valid.
# File 3d3v_contacts.csv is valid.
# File 4jrx_contacts.csv is valid.
# File 1kj2_contacts.csv is valid.
# File 5hho_contacts.csv is valid.
# File 8ryp_contacts.csv is valid.
# File 2esv_contacts.csv is valid.
# File 4n0c_contacts.csv is valid.
# File 3gsn_contacts.csv is valid.
# File 7rrg_contacts.csv is valid.
# File 2j8u_contacts.csv is valid.
# File 7n5p_contacts.csv is valid.
# File 4qok_contacts.csv is valid.
# File 6eqb_contacts.csv is valid.
# File 3hg1_contacts.csv is valid.
# File 6bj2_contacts.csv is valid.
# File 5c09_contacts.csv is valid.
# File 5c0c_contacts.csv is valid.
# File 5men_contacts.csv is valid.
# File 7n2n_contacts.csv is valid.
# File 3tpu_contacts.csv is valid.
# File 2ol3_contacts.csv is valid.
# File 6r2l_contacts.csv is valid.
# File 6bj8_contacts.csv is valid.
# File 3d39_contacts.csv is valid.
# File 7ndq_contacts.csv is valid.
# File 2vlk_contacts.csv is valid.
# File 6rp9_contacts.csv is valid.
# File 6vma_contacts.csv is valid.
# File 7ow6_contacts.csv is valid.
# File 2p5w_contacts.csv is valid.
# File 7q9b_contacts.csv is valid.
# File 1ao7_contacts.csv is valid.
# File 5w1v_contacts.csv is valid.
# File 6uon_contacts.csv is valid.
# File 3tjh_contacts.csv is valid.
# File 5nmf_contacts.csv is valid.
# File 5m02_contacts.csv is valid.
# File 6am5_contacts.csv is valid.
# File 5jzi_contacts.csv is valid.
# File 6mtm_contacts.csv is valid.
# File 7nme_contacts.csv is valid.
# File 2bnr_contacts.csv is valid.
# File 7pbe_contacts.csv is valid.
# File 4l3e_contacts.csv is valid.
# File 5e9d_contacts.csv is valid.
# File 1fo0_contacts.csv is valid.
# File 8gvi_contacts.csv is valid.
# File 4pri_contacts.csv is valid.
# File 8v51_contacts.csv is valid.
# File 6l9l_contacts.csv is valid.
# File 8enh_contacts.csv is valid.
# File 4qrp_contacts.csv is valid.
# File 7n1e_contacts.csv is valid.
# File 5nmg_contacts.csv is valid.
# File 6zkw_contacts.csv is valid.
# File 5w1w_contacts.csv is valid.
# File 5nqk_contacts.csv is valid.
# File 7q99_contacts.csv is valid.
# File 5sws_contacts.csv is valid.
# File 3sjv_contacts.csv is valid.
# File 3mv7_contacts.csv is valid.
# File 4prp_contacts.csv is valid.
# File 3qfj_contacts.csv is valid.
# File 7n6e_contacts.csv is valid.
# File 4g8g_contacts.csv is valid.
# File 2vlj_contacts.csv is valid.
# File 6rpb_contacts.csv is valid.
# File 5tje_contacts.csv is valid.
# File 5d2l_contacts.csv is valid.
# File 3kxf_contacts.csv is valid.
# File 7dzm_contacts.csv is valid.
# File 3ffc_contacts.csv is valid.
# File 7pbc_contacts.csv is valid.
# File 8d5q_contacts.csv is valid.
# File 8v50_contacts.csv is valid.
# File 4prh_contacts.csv is valid.
# File 5yxn_contacts.csv is valid.
# File 3dxa_contacts.csv is valid.
# File 8i5c_contacts.csv is valid.
# File 1bd2_contacts.csv is valid.
# File 6vrm_contacts.csv is valid.
# File 8i5d_contacts.csv is valid.
# File 7r80_contacts.csv is valid.
# File 8cx4_contacts.csv is valid.
# File 6uln_contacts.csv is valid.
# File 6vmx_contacts.csv is valid.
# File 8wte_contacts.csv is valid.
# File 7n5c_contacts.csv is valid.
# File 2vlr_contacts.csv is valid.
# File 5xot_contacts.csv is valid.
# File 5m01_contacts.csv is valid.
# File 7nmf_contacts.csv is valid.
# File 6rsy_contacts.csv is valid.
# File 1g6r_contacts.csv is valid.
# File 7q9a_contacts.csv is valid.
# File 5nme_contacts.csv is valid.
# File 6tmo_contacts.csv is valid.
# File 7ow5_contacts.csv is valid.
# File 6vm8_contacts.csv is valid.
# File 2e7l_contacts.csv is valid.
# File 5d2n_contacts.csv is valid.
# File 3kpr_contacts.csv is valid.
# File 5c07_contacts.csv is valid.
# File 7ndu_contacts.csv is valid.
# File 3qeq_contacts.csv is valid.
# File 7rtr_contacts.csv is valid.
# File 8f5a_contacts.csv is valid.
# File 7n1f_contacts.csv is valid.
# File 6avf_contacts.csv is valid.
# File 1qrn_contacts.csv is valid.
# File 6d78_contacts.csv is valid.
# File 4eup_contacts.csv is valid.
# File 7na5_contacts.csv is valid.
# File 5xov_contacts.csv is valid.
# File 8es8_contacts.csv is valid.
# File 1oga_contacts.csv is valid.
# File 2bnq_contacts.csv is valid.
# File 2oi9_contacts.csv is valid.
# File 6vqo_contacts.csv is valid.
# File 6vmc_contacts.csv is valid.
# File 6vm9_contacts.csv is valid.
# File 7dzn_contacts.csv is valid.
# File 6ulr_contacts.csv is valid.
# File 5brz_contacts.csv is valid.
# File 3o4l_contacts.csv is valid.
# File 6rpa_contacts.csv is valid.
# File 7ndt_contacts.csv is valid.
# File 3kps_contacts.csv is valid.
# File 8yiv_contacts.csv is valid.
# File 7phr_contacts.csv is valid.
# File 8qfy_contacts.csv is valid.
# File 8yj2_contacts.csv is valid.
# File 7nmg_contacts.csv is valid.
# File 5yxu_contacts.csv is valid.
# File 5m00_contacts.csv is valid.
# File 4g9f_contacts.csv is valid.
# File 5wkh_contacts.csv is valid.
# File 8rro_contacts.csv is valid.
# File 8es9_contacts.csv is valid.
# File 6avg_contacts.csv is valid.
# File 3qdj_contacts.csv is valid.
# File 4qrr_contacts.csv is valid.
# File 6vrn_contacts.csv is valid.
# File 3qdm_contacts.csv is valid.
# File 8dnt_contacts.csv is valid.
# File 6amu_contacts.csv is valid.
# File 2jcc_contacts.csv is valid.
# File 5e6i_contacts.csv is valid.
# File 3pwp_contacts.csv is valid.
# File 8rym_contacts.csv is valid.
# File 3qdg_contacts.csv is valid.
# File 5nht_contacts.csv is valid.
# File 4mvb_contacts.csv is valid.
# File 7jwi_contacts.csv is valid.
# File 3e2h_contacts.csv is valid.
# File 4mji_contacts.csv is valid.
# File 5bs0_contacts.csv is valid.
# File 3vxs_contacts.csv is valid.
# File 5hyj_contacts.csv is valid.
# File 2pye_contacts.csv is valid.
# File 8eo8_contacts.csv is valid.
# File 7n2s_contacts.csv is valid.
# File 8rlu_contacts.csv is valid.
# File 3mv9_contacts.csv is valid.
# File 2uwe_contacts.csv is valid.
# File 5swz_contacts.csv is valid.
# File 5hhm_contacts.csv is valid.
# File 3w0w_contacts.csv is valid.
# File 6zky_contacts.csv is valid.
# File 4mnq_contacts.csv is valid.
# File 2nx5_contacts.csv is valid.
# File 6p64_contacts.csv is valid.
# File 5c0a_contacts.csv is valid.
# File 7qpj_contacts.csv is valid.
# File 3pqy_contacts.csv is valid.
# File 7rm4_contacts.csv is valid.
# File 7pdw_contacts.csv is valid.
# File 5tez_contacts.csv is valid.
# File 3h9s_contacts.csv is valid.
# File 4jff_contacts.csv is valid.
# File 6tro_contacts.csv is valid.
# File 5euo_contacts.csv is valid.
# File 8rlt_contacts.csv is valid.
# File 1qsf_contacts.csv is valid.
# File 7n2r_contacts.csv is valid.
# File 8rj5_contacts.csv is valid.
# File 6dkp_contacts.csv is valid.
# File 8gon_contacts.csv is valid.
# File 3vxu_contacts.csv is valid.
# File 5til_contacts.csv is valid.
# File 6g9q_contacts.csv is valid.
# File 3vxr_contacts.csv is valid.
# File 8gvg_contacts.csv is valid.
# File 4mxq_contacts.csv is valid.
# File 1lp9_contacts.csv is valid.
# File 6q3s_contacts.csv is valid.
# File 6eqa_contacts.csv is valid.
# File 4n5e_contacts.csv is valid.
# File 3vxm_contacts.csv is valid.
# File 7rk7_contacts.csv is valid.
# File 3mv8_contacts.csv is valid.
# File 2f54_contacts.csv is valid.
# File 6zkx_contacts.csv is valid.
# File 2f53_contacts.csv is valid.
